# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
temp_data = pd.read_csv('Environment_Temperature_change_E_All_Data_NOFLAG.csv')
temp_data.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   �C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   �C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   �C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   �C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   �C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# ...

# %%
# selecting features
X = temp_data['Y1961'].values
y = temp_data['Months'].values

# %%
# X data
X
# Out:
# array([ 0.777,  1.95 , -1.743, ...,  0.378,  0.165,  0.26 ])

# %%
# y data
y
# Out:
# array(['January', 'January', 'February', ..., 'Sep�Oct�Nov',
#        'Meteorological year', 'Meteorological year'], dtype=object)

# %%
X = X.reshape(-1, 1)
X
# Out:
# array([[ 0.777],
#        [ 1.95 ],
#        [-1.743],
#        ...,
#        [ 0.378],
#        [ 0.165],
#        [ 0.26 ]])

# %%
#  split (80/20)one for testing and one for training to make presumptions, and compare
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=.8, test_size=.2, random_state=100)

# %%
print(f'X_Train shape [{x_train.shape}]')
print(f'X_Test shape [{x_test.shape}]')
print(f'y_Train shape [{y_train.shape}]')
print(f'y_Test shape [{y_test.shape}]')
# Out:
# X_Train shape [(7724, 1)]
# X_Test shape [(1932, 1)]
# y_Train shape [(7724,)]
# y_Test shape [(1932,)]

# %%
plt.scatter(x_train, y_train, color='blue')
plt.xlabel('Temperature Deviations')
plt.ylabel('Months')
plt.title('1961')
# Out:
# Text(0.5, 1.0, '1961')

# %%
plt.scatter(x_test, y_test, color='teal')
plt.xlabel('Temperature Deviations')
plt.ylabel('Months')
plt.title('1961')
# Out:
# Text(0.5, 1.0, '1961')

# %%
y = y.reshape(-1, 1)
y
# Out:
# array([['January'],
#        ['January'],
#        ['February'],
#        ...,
#        ['Sep�Oct�Nov'],
#        ['Meteorological year'],
#        ['Meteorological year']], dtype=object)

# %%
X = temp_data['Y2019'].values
y = temp_data['Months'].values

# %%
X = X.reshape(-1, 1)
X
# Out:
# array([[2.951],
#        [1.95 ],
#        [0.086],
#        ...,
#        [0.378],
#        [1.297],
#        [0.26 ]])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=.8, test_size=.2, random_state=100)

# %%
print(f'X_Train shape [{x_train.shape}]')
print(f'X_Test shape [{x_test.shape}]')
print(f'y_Train shape [{y_train.shape}]')
print(f'y_Test shape [{y_test.shape}]')
# Out:
# X_Train shape [(7724, 1)]
# X_Test shape [(1932, 1)]
# y_Train shape [(7724,)]
# y_Test shape [(1932,)]

# %%
plt.scatter(x_train, y_train, color='blue')
plt.xlabel('Temperature Deviations')
plt.ylabel('Months')
plt.title('2019')
# Out:
# Text(0.5, 1.0, '2019')

# %%
plt.scatter(x_test, y_test, color='teal')
plt.xlabel('Temperature Deviations')
plt.ylabel('Months')
plt.title('2019')
# Out:
# Text(0.5, 1.0, '2019')
